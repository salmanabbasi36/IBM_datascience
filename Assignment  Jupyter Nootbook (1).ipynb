# %% [markdown]
# # My jupyter notebook on IBM Watson Studio

# %% [markdown]
# __Salman Khan__
#
# I want to became a Machine Learning Engineer

# %% [markdown]
# *In recent time data hase proven its worth in almost every field of life.
#
# *Data science has lifted up research in every field.
#
# *I believe Data is new oil.*

# %% [markdown]
# ### My code is going to find greater number between non equal numbers.

# %%
a=float(input("Enter first number  "))
b=float(input("Enter second number  "))
if(a>b):
    print ("a is greater")
else:
    print("b is greater")
# Out:
# Enter first number  45687951321
# Enter second number  6476513219746564
# b is greater

# %% [markdown]
# #### Bulleted List is here
# 1- Bulleted list
# * This is bulleted list
# * This is another bulleted list
#
# 2- Strike Through
#   ~~Strike Through~~
# 3- Link
# [To open IBM site click on me](www.ibm.com)
